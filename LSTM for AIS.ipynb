# %%
import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

import keras
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data)-look_back):
        dataX.append(signal_data[i:(i+look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

class CustomHistory(tf.keras.callbacks.Callback):
    def init(self):
        self.train_loss = []
        self.val_loss = []
        
    def on_epoch_end(self, batch, logs={}):
        self.train_loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))

look_back = 40

# 1. 데이터셋 생성하기
signal_data = np.cos(np.arange(1600)*(20*np.pi/1000))[:,None]

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0, 1))
signal_data = scaler.fit_transform(signal_data)

# 데이터 분리
train = signal_data[0:800]
val = signal_data[800:1200]
test = signal_data[1200:]

# 데이터셋 생성
x_train, y_train = create_dataset(train, look_back)
x_val, y_val = create_dataset(val, look_back)
x_test, y_test = create_dataset(test, look_back)

# 데이터셋 전처리
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
# Out:
# Using TensorFlow backend.

# %%
# 2. 모델 구성
model = Sequential()
model.add(LSTM(32, batch_input_shape=(1, look_back, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))

# %%
# 3. 모델 학습과정 설정
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 4. 모델 학습시키기
custom_hist = CustomHistory()
custom_hist.init()

for i in range(200):
    model.fit(x_train, y_train, epochs=1, batch_size=1, shuffle=False, callbacks=[custom_hist], validation_data=(x_val,y_val))
    model.reset_states()
# Out:
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 6s 8ms/sample - loss: 0.0204 - val_loss: 0.0080
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0087 - val_loss: 0.0014
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0086 - val_loss: 0.0059
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0074 - val_loss: 0.0043
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0041 - val_loss: 5.5288e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0044 - val_loss: 0.0011
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0039 - val_loss: 0.0023
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0036 - val_loss: 0.0026
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0041 - val_loss: 0.0027
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0043 - val_loss: 0.0052
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0035 - val_loss: 7.0359e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0027 - val_loss: 0.0014
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0034 - val_loss: 0.0046
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0031 - val_loss: 0.0025
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0027 - val_loss: 0.0021
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0033 - val_loss: 0.0026
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0042 - val_loss: 0.0020
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0028 - val_loss: 0.0026
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0036 - val_loss: 0.0019
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0035 - val_loss: 8.6759e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 0.0029
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0026 - val_loss: 0.0013
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0034 - val_loss: 0.0021
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0032 - val_loss: 0.0091
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0029 - val_loss: 0.0020
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 0.0034
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0030 - val_loss: 0.0019
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0030 - val_loss: 0.0015
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0036 - val_loss: 0.0016
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0026 - val_loss: 0.0011
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0027 - val_loss: 0.0025
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0032 - val_loss: 0.0051
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0032 - val_loss: 0.0010
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0025 - val_loss: 0.0025
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 0.0011
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0032 - val_loss: 0.0019
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0027 - val_loss: 0.0033
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 4.2091e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 0.0017
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0024 - val_loss: 0.0013
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0026 - val_loss: 0.0012
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0028 - val_loss: 0.0020
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0026 - val_loss: 6.3817e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0025 - val_loss: 0.0012
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0024 - val_loss: 7.6689e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0025 - val_loss: 0.0106
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0027 - val_loss: 0.0023
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0024 - val_loss: 0.0015
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 8.2364e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0027 - val_loss: 8.4481e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0025 - val_loss: 3.4167e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 0.0016
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 0.0046
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0026 - val_loss: 0.0023
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0035 - val_loss: 0.0024
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0028 - val_loss: 3.4261e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 6.3107e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 4.4024e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 8.6330e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 0.0022
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0024 - val_loss: 4.3765e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 2.4380e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0025 - val_loss: 8.0036e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0028 - val_loss: 0.0035
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 0.0012
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 0.0012
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0024 - val_loss: 4.3314e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 1.1594e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 0.0018
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 0.0017
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 3.6121e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0024 - val_loss: 6.7605e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0024 - val_loss: 7.4069e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0026 - val_loss: 2.2335e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 8.0432e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 0.0011
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 4.3049e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 0.0012
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 2.0788e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 0.0013
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0024 - val_loss: 4.2652e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 3.0816e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 1.5071e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 2.3418e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 2.1244e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 5.8268e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 6.5645e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 2.9059e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 5.0574e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 4.7537e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 4.8590e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 7.2427e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 7.4466e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 2.9454e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 1.0126e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 6.6289e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 1.2940e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 2.7321e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 0.0019
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 2.4577e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 9.6467e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.2714e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 4.1254e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 0.0010
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 7.1919e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 2.9961e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 1.8749e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.2480e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 5.6559e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 3.0137e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0018 - val_loss: 2.2171e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 0.0011
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 1.7263e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 0.0019
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 7.0879e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 8.4811e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 9.3381e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 9.5736e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 2.9971e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.3948e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.7837e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 4.1156e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 2.9344e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 7.9568e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 3.9976e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 3.3901e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0024 - val_loss: 1.7827e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 1.7616e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.9428e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 7.2870e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 2.7855e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 2.2673e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 0.0011
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 1.9672e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 5.5463e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 5.0211e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 2.8473e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 2.2190e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.5131e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0018 - val_loss: 3.9842e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 7.3920e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 3.7319e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 2.1667e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 8.5796e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 3.2898e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0018 - val_loss: 4.6722e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 2.1162e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0018 - val_loss: 1.2256e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0018 - val_loss: 2.8177e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 1.6333e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 1.5866e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 2.4069e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 1.1373e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 8.4733e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 2.2161e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 2.2427e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 5.3323e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 8.3469e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 0.0015
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 2.7535e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 3.2402e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 1.5529e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 6.5950e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 5.4689e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.8040e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.9985e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.1711e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 1.9578e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0017 - val_loss: 4.8862e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 4.3196e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 2.2670e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 7.1070e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 2.7293e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 3.7453e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 2.0182e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 3.5376e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 8.8584e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0022 - val_loss: 1.1232e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 7.4251e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 6.4598e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.5634e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 3.3354e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 2.7136e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 2.3363e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 2.1661e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0018 - val_loss: 7.0905e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 2.5317e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0017 - val_loss: 1.3556e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 6.9121e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 4.0508e-06
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 1.9826e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0023 - val_loss: 1.8952e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 5.6614e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 1.0378e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0021 - val_loss: 9.7084e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 2.8219e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 3.5934e-05
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 1.7777e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0019 - val_loss: 4.2499e-04
# Train on 760 samples, validate on 360 samples
# 760/760 [==============================] - 3s 4ms/sample - loss: 0.0020 - val_loss: 2.8899e-04

# %%
# 5. 학습과정 살펴보기
plt.plot(custom_hist_hist.train_loss)
plt.plot(custom_hist.val_loss)
plt.ylim(0.0,0.15)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','val'],loc='upper left')
plt.show()

# %%
# 6. 모델 평가하기
trainScore = model.evaluate(x_train, y_train, batch_size=1, verbose=0)
model.reset_states()
print('Train Score: ', trainScore)
valScore = model.evaluate(x_val, y_val, batch_size=1, verbose=0)
model.reset_states()
print('Validataion Score: ', valScore)
testScore = model.evaluate(x_test, y_test, batch_size=1, verbose=0)
model.reset_states()
print('Test Score: ', testScore)

# 7. 모델 사용하기
look_ahead = 250
xhat = x_test[0]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([xhat]), batch_size=1)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:],prediction])
    
plt.figure(figsize=(12,5))
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),y_test[:look_ahead],label="test function")
plt.legend()
plt.show()
# Out:
# Train Score:  0.0002860126141441517
# Validataion Score:  0.0002877811875906547
# Test Score:  0.0002877811875906547
